# %%
# with open ('data/iris.csv') as f:
    # for line in f:
        # print(line)
        
# czytanie pliku inny sposób 

import csv
import pandas as pd

#read_csv 

df = pd.read_csv('http://lab.galka.cc/ds-files/iris.csv')


df

#pd.read_csv("01-python_csv.ipynb")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("LaqnData_02_short.csv")
df
# Out:
#          ReadingDateTime Site Species  Value                          Units  \
# 0    2005-05-18 03:30:00  BX1    WSPD    1.4                            m/s
# 1    2005-05-11 04:30:00  BX1    WSPD    2.5                            m/s
# 2    2005-06-25 08:00:00  BX1    FINE   30.0                          ug/m3
# 3    2005-03-28 05:45:00  BX1    FINE   41.0                          ug/m3
# 4    2005-09-01 01:30:00  BX1    FINE    9.0                          ug/m3
# 5    2005-03-28 04:15:00  BX1    WDIR  287.0                             oN
# 6    2005-10-13 12:15:00  BX1    PM10    NaN  ug m-3 reference equiv by VCM
# 7    2005-04-14 13:30:00  BX1    FINE    7.0                          ug/m3
# 8    2005-01-27 02:00:00  BX1    FINE   12.0                          ug/m3
# 9    2005-10-02 18:15:00  BX1    FINE    8.0                          ug/m3
# 10   2005-12-26 22:00:00  BX1    WSPD    2.5                            m/s
# ...

# %%
df['ReadingDateTime'] = pd.to_datetime(df.ReadingDateTime)

df['DOB1'] = df['ReadingDateTime'].dt.strftime('%m/%d/%Y')
print (df)
# Out:
#         ReadingDateTime Site Species  Value                          Units  \
# 0   2005-05-18 03:30:00  BX1    WSPD    1.4                            m/s
# 1   2005-05-11 04:30:00  BX1    WSPD    2.5                            m/s
# 2   2005-06-25 08:00:00  BX1    FINE   30.0                          ug/m3
# 3   2005-03-28 05:45:00  BX1    FINE   41.0                          ug/m3
# 4   2005-09-01 01:30:00  BX1    FINE    9.0                          ug/m3
# 5   2005-03-28 04:15:00  BX1    WDIR  287.0                             oN
# 6   2005-10-13 12:15:00  BX1    PM10    NaN  ug m-3 reference equiv by VCM
# 7   2005-04-14 13:30:00  BX1    FINE    7.0                          ug/m3
# 8   2005-01-27 02:00:00  BX1    FINE   12.0                          ug/m3
# 9   2005-10-02 18:15:00  BX1    FINE    8.0                          ug/m3
# 10  2005-12-26 22:00:00  BX1    WSPD    2.5                            m/s
# ...

# %%
df
# Out:
#          ReadingDateTime Site Species  Value                          Units  \
# 0    2005-05-18 03:30:00  BX1    WSPD    1.4                            m/s
# 1    2005-05-11 04:30:00  BX1    WSPD    2.5                            m/s
# 2    2005-06-25 08:00:00  BX1    FINE   30.0                          ug/m3
# 3    2005-03-28 05:45:00  BX1    FINE   41.0                          ug/m3
# 4    2005-09-01 01:30:00  BX1    FINE    9.0                          ug/m3
# 5    2005-03-28 04:15:00  BX1    WDIR  287.0                             oN
# 6    2005-10-13 12:15:00  BX1    PM10    NaN  ug m-3 reference equiv by VCM
# 7    2005-04-14 13:30:00  BX1    FINE    7.0                          ug/m3
# 8    2005-01-27 02:00:00  BX1    FINE   12.0                          ug/m3
# 9    2005-10-02 18:15:00  BX1    FINE    8.0                          ug/m3
# 10   2005-12-26 22:00:00  BX1    WSPD    2.5                            m/s
# ...

# %%
# df.sample(500).to.csv(LaqnData_02_short.csv)

# %%
df.dropna(0)
df
# Out:
#          ReadingDateTime Site Species  Value                          Units  \
# 0    2005-05-18 03:30:00  BX1    WSPD    1.4                            m/s
# 1    2005-05-11 04:30:00  BX1    WSPD    2.5                            m/s
# 2    2005-06-25 08:00:00  BX1    FINE   30.0                          ug/m3
# 3    2005-03-28 05:45:00  BX1    FINE   41.0                          ug/m3
# 4    2005-09-01 01:30:00  BX1    FINE    9.0                          ug/m3
# 5    2005-03-28 04:15:00  BX1    WDIR  287.0                             oN
# 6    2005-10-13 12:15:00  BX1    PM10    NaN  ug m-3 reference equiv by VCM
# 7    2005-04-14 13:30:00  BX1    FINE    7.0                          ug/m3
# 8    2005-01-27 02:00:00  BX1    FINE   12.0                          ug/m3
# 9    2005-10-02 18:15:00  BX1    FINE    8.0                          ug/m3
# 10   2005-12-26 22:00:00  BX1    WSPD    2.5                            m/s
# ...

# %%
df = df.dropna()
# dropna(subset =['Value])

# %%
df.fillna(0, inplace=True)
df
# Out:
#          ReadingDateTime Site Species  Value                          Units  \
# 0    2005-05-18 03:30:00  BX1    WSPD    1.4                            m/s
# 1    2005-05-11 04:30:00  BX1    WSPD    2.5                            m/s
# 2    2005-06-25 08:00:00  BX1    FINE   30.0                          ug/m3
# 3    2005-03-28 05:45:00  BX1    FINE   41.0                          ug/m3
# 4    2005-09-01 01:30:00  BX1    FINE    9.0                          ug/m3
# 5    2005-03-28 04:15:00  BX1    WDIR  287.0                             oN
# 7    2005-04-14 13:30:00  BX1    FINE    7.0                          ug/m3
# 8    2005-01-27 02:00:00  BX1    FINE   12.0                          ug/m3
# 9    2005-10-02 18:15:00  BX1    FINE    8.0                          ug/m3
# 10   2005-12-26 22:00:00  BX1    WSPD    2.5                            m/s
# 11   2005-05-12 20:30:00  BX1      CO    0.5                         mg m-3
# ...

# %%
CO = df[df.Species =='CO']
CO

WSPD = df[df.Species =='WSPD']
WSPD
# Out:
#          ReadingDateTime Site Species  Value Units Provisional or Ratified
# 0    2005-05-18 03:30:00  BX1    WSPD    1.4   m/s                       P
# 1    2005-05-11 04:30:00  BX1    WSPD    2.5   m/s                       P
# 10   2005-12-26 22:00:00  BX1    WSPD    2.5   m/s                       P
# 17   2005-01-11 04:30:00  BX1    WSPD    2.1   m/s                       P
# 24   2005-05-10 16:45:00  BX1    WSPD    1.5   m/s                       P
# 26   2005-07-03 11:15:00  BX1    WSPD    2.2   m/s                       P
# 31   2005-06-26 05:30:00  BX1    WSPD    2.4   m/s                       P
# 32   2005-08-10 02:15:00  BX1    WSPD    0.9   m/s                       P
# 33   2005-01-29 20:30:00  BX1    WSPD    1.6   m/s                       P
# 35   2005-11-14 17:00:00  BX1    WSPD    1.3   m/s                       P
# 40   2005-05-25 08:30:00  BX1    WSPD    3.0   m/s                       P
# ...

# %%
CO.join(WSPD, how='left', lsuffix='_CO', rsuffix='_SPD').rename(columns=lambda x: x.split('_')[1] if x.startswith('Value') else x)
# Out:
#       ReadingDateTime_CO Site_CO Species_CO   CO Units_CO  \
# 11   2005-05-12 20:30:00     BX1         CO  0.5   mg m-3
# 14   2005-08-12 01:30:00     BX1         CO  0.2   mg m-3
# 29   2005-09-23 20:15:00     BX1         CO  0.5   mg m-3
# 36   2005-09-11 19:00:00     BX1         CO  1.2   mg m-3
# 37   2005-09-29 23:15:00     BX1         CO  0.2   mg m-3
# 41   2005-04-14 10:00:00     BX1         CO  0.2   mg m-3
# 45   2005-05-16 07:15:00     BX1         CO  0.5   mg m-3
# 48   2005-01-18 19:30:00     BX1         CO  0.3   mg m-3
# 57   2005-10-19 02:00:00     BX1         CO  0.3   mg m-3
# 64   2005-07-19 04:30:00     BX1         CO  NaN   mg m-3
# 69   2005-03-15 03:00:00     BX1         CO  0.2   mg m-3
# 76   2005-11-07 18:45:00     BX1         CO  0.1   mg m-3
# 79   2005-11-06 19:45:00     BX1         CO  0.2   mg m-3
# 87   2005-07-05 15:45:00     BX1         CO  0.2   mg m-3
# 90   2005-05-06 18:45:00     BX1         CO  0.1   mg m-3
# ...

# %%
# movie_metadata
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("movie_metadata.csv", parse_dates = ['title_year'], index_col = ['title_year'])

keywords = df.plot_keywords.str.split('|')
df['plot_keywords'] = keywords
df.plot.keywords
df = df.join

df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-54bb634c1112> in <module>()
#       8 keywords = df.plot_keywords.str.split('|')
#       9 df['plot_keywords'] = keywords
# ---> 10 df.plot.keywords
#      11
#      12
#
# AttributeError: 'FramePlotMethods' object has no attribute 'keywords'

# %%
# df.title_year

# %%
df2 = df['title_year'] = pd.to_datetime(df.title_year,)

df2
# Out:
# 0      1970-01-01 00:00:00.000002009
# 1      1970-01-01 00:00:00.000002007
# 2      1970-01-01 00:00:00.000002015
# 3      1970-01-01 00:00:00.000002012
# 4                                NaT
# 5      1970-01-01 00:00:00.000002012
# 6      1970-01-01 00:00:00.000002007
# 7      1970-01-01 00:00:00.000002010
# 8      1970-01-01 00:00:00.000002015
# 9      1970-01-01 00:00:00.000002009
# 10     1970-01-01 00:00:00.000002016
# 11     1970-01-01 00:00:00.000002006
# 12     1970-01-01 00:00:00.000002008
# 13     1970-01-01 00:00:00.000002006
# 14     1970-01-01 00:00:00.000002013
# 15     1970-01-01 00:00:00.000002013
# 16     1970-01-01 00:00:00.000002008
# 17     1970-01-01 00:00:00.000002012
# 18     1970-01-01 00:00:00.000002011
# 19     1970-01-01 00:00:00.000002012
# 20     1970-01-01 00:00:00.000002014
# 21     1970-01-01 00:00:00.000002012
# 22     1970-01-01 00:00:00.000002010
# 23     1970-01-01 00:00:00.000002013
# 24     1970-01-01 00:00:00.000002007
# ...

# %%
df.set_index('title_year')
# Out:
#                                           color       director_name  \
# title_year
# 1970-01-01 00:00:00.000002009             Color       James Cameron
# 1970-01-01 00:00:00.000002007             Color      Gore Verbinski
# 1970-01-01 00:00:00.000002015             Color          Sam Mendes
# 1970-01-01 00:00:00.000002012             Color   Christopher Nolan
# NaT                                         NaN         Doug Walker
# 1970-01-01 00:00:00.000002012             Color      Andrew Stanton
# 1970-01-01 00:00:00.000002007             Color           Sam Raimi
# 1970-01-01 00:00:00.000002010             Color        Nathan Greno
# 1970-01-01 00:00:00.000002015             Color         Joss Whedon
# 1970-01-01 00:00:00.000002009             Color         David Yates
# 1970-01-01 00:00:00.000002016             Color         Zack Snyder
# 1970-01-01 00:00:00.000002006             Color        Bryan Singer
# 1970-01-01 00:00:00.000002008             Color        Marc Forster
# ...

# %%
# split

# %%
import pandas as pd
df = pd.read_excel('iris.xls', sheetname = 'iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.groupby('species').median()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %%
aggregations = {
    'sepal_length': [min, max],    
    'sepal_width': [min, max],
    'petal_width': [min, max],
    'petal_length': [min, max]
}

df.groupby('species').agg(aggregations)
# Out:
#            sepal_length      sepal_width      petal_width      petal_length  \
#                     min  max         min  max         min  max          min
# species
# setosa              4.3  5.8         2.3  4.4         0.1  0.6          1.0
# versicolor          4.9  7.0         2.0  3.4         1.0  1.8          3.0
# virginica           4.9  7.9         2.2  3.8         1.4  2.5          4.5
#
#
#             max
# species
# setosa      1.9
# versicolor  5.1
# virginica   6.9

# %%
aggregations2 = {
    'sepal_length': [min, max],    
    'sepal_width': [min, max],
    'petal_width': [min, max],
    'petal_length': [min, max]
}

df.groupby('species').agg(aggregations2)
# Out:
#            sepal_length      sepal_width      petal_width      petal_length  \
#                     min  max         min  max         min  max          min
# species
# setosa              4.3  5.8         2.3  4.4         0.1  0.6          1.0
# versicolor          4.9  7.0         2.0  3.4         1.0  1.8          3.0
# virginica           4.9  7.9         2.2  3.8         1.4  2.5          4.5
#
#
#             max
# species
# setosa      1.9
# versicolor  5.1
# virginica   6.9

# %%
pd.__version__
# Out:
# '0.19.2'

# %%
import json

# %%
data  = {
    'name' : 'Jan'
    'age' : 23
        
    
}
# Out:
#   File "<ipython-input-116-8d537d15e322>", line 1
#     currency_json = “”"
#                      ^
# SyntaxError: invalid character in identifier

# %%
currency_json = """

{"table":"","currency":"dolar amerykański","code":"USD","rates":[{"no":"064/C/NBP/2016","effectiveDate":"2016-04-04","bid":3.6929,"ask":3.7675}]}

"""

# %%
import json

data = {

    'name': 'Jan',

    'surname': 'Kowalski',

    'age': 23

}



print(type(data))



data_json = json.dumps(data)

print(data_json)



print(type(data_json))



currency_json = """

{"table":"A","currency":"dolar amerykański","code":"USD","rates":[{"no":"064/C/NBP/2016","effectiveDate":"2016-04-04","bid":3.6929,"ask":3.7675}]}

"""

print(json.loads(currency_json))
# Out:
# <class 'dict'>
# {"name": "Jan", "surname": "Kowalski", "age": 23}
# <class 'str'>
# {'table': 'A', 'currency': 'dolar amerykański', 'code': 'USD', 'rates': [{'no': '064/C/NBP/2016', 'effectiveDate': '2016-04-04', 'bid': 3.6929, 'ask': 3.7675}]}

# %%
import requests

tabela_kursow = 'A'

url = 'http://api.nbp.pl/api/exchangerates/tables/{}/'.format(tabela_kursow)

resp = requests.get(url)

    if resp.status_code == 200:

          if 'content-type' in resp.headers and 'application/json' in resp.headers['content-type']:

    data = resp.json()

Message Input
# Out:
#   File "<ipython-input-121-2e8c05cac4c3>", line 9
#     if resp.status_code == 200:
#     ^
# IndentationError: unexpected indent

# %%
# http://api.nbp.pl/api/exchangerates/rates/a/gbp/2012-01-01/2012-01-31/

# %%
import requests

tabela_kursow = 'A'

url = 'http://api.nbp.pl/api/exchangerates/tables/{}/'.format(tabela_kursow)

resp = requests.get(url)

if resp.status_code == 200:

    if 'content-type' in resp.headers and 'application/json' in resp.headers['content-type']:

        data = resp.json()
        print(resp.status_code)
        print(resp.headers)

    print(resp.headers['content-type'])

print(data)
# Out:
# 200
# {'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Content-Length': '839', 'Content-Type': 'application/json; charset=utf-8', 'Content-Encoding': 'gzip', 'Expires': '-1', 'ETag': '"kyWFRXcibnDz51M5NkcWqsuBWSfBtdxrESoXnr31vk0="', 'Date': 'Sat, 15 Dec 2018 15:29:35 GMT'}
# application/json; charset=utf-8
# ...

# %%
import requests

tabela_kursow = 'C'

url = 'http://api.nbp.pl/api/exchangerates/tables/{}/'.format(tabela_kursow)

resp = requests.get(url)

if resp.status_code == 200:

    if 'content-type' in resp.headers and 'application/json' in resp.headers['content-type']:
        data = resp.json()
        print(resp.status_code)
        print(resp.headers)
        
    print(resp.headers['content-type'])
    df3 = resp.headers['content-type']
print(data)
# Out:
# 200
# {'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Content-Length': '1007', 'Content-Type': 'application/json; charset=utf-8', 'Expires': '-1', 'ETag': '"tXZIwBmmATgUPSgxAtqtMQELlsE1ZBt5MRkZ1f5qQ4s="', 'Date': 'Sat, 15 Dec 2018 15:30:22 GMT'}
# application/json; charset=utf-8
# ...

# %%
print(df3)
# Out:
# application/json; charset=utf-8

# %%
code_USD = 'USD'
code_EUR = 'EUR'
start_date = "2018-04-01"
end_date = "2018-04-30"
url_USD = 'http://api.nbp.pl/api/exchangerates/rates/{}/{}/{}/{}/'.format('A', code_USD, start_date, end_date)
url_EUR = 'http://api.nbp.pl/api/exchangerates/rates/{}/{}/{}/{}/'.format('A', code_EUR, start_date, end_date)
resp_USD = requests.get(url_USD)
resp_EUR = requests.get(url_EUR)
if resp_USD.status_code == 200:
    if 'content-type' in resp_USD.headers and 'application/json' in resp_USD.headers['content-type']:
        data_USD = resp_USD.json()
        
if resp_EUR.status_code == 200:
    if 'content-type' in resp_EUR.headers and 'application/json' in resp_EUR.headers['content-type']:
        data_EUR = resp_EUR.json()
print(resp_EUR.status_code)
print(resp_USD.status_code)
print(resp.headers['content-type'])
print(data_EUR)
print(data_USD)


df1 = data_USD
df2 = data_EUR
# Out:
# 200
# 200
# application/json; charset=utf-8
# ...

# %%
df1
# Out:
# {'code': 'USD',
#  'currency': 'dolar amerykański',
#  'rates': [{'effectiveDate': '2018-04-03',
#    'mid': 3.4177,
#    'no': '065/A/NBP/2018'},
#   {'effectiveDate': '2018-04-04', 'mid': 3.4224, 'no': '066/A/NBP/2018'},
#   {'effectiveDate': '2018-04-05', 'mid': 3.4301, 'no': '067/A/NBP/2018'},
#   {'effectiveDate': '2018-04-06', 'mid': 3.4315, 'no': '068/A/NBP/2018'},
#   {'effectiveDate': '2018-04-09', 'mid': 3.4174, 'no': '069/A/NBP/2018'},
#   {'effectiveDate': '2018-04-10', 'mid': 3.4068, 'no': '070/A/NBP/2018'},
#   {'effectiveDate': '2018-04-11', 'mid': 3.3859, 'no': '071/A/NBP/2018'},
#   {'effectiveDate': '2018-04-12', 'mid': 3.3924, 'no': '072/A/NBP/2018'},
#   {'effectiveDate': '2018-04-13', 'mid': 3.3862, 'no': '073/A/NBP/2018'},
#   {'effectiveDate': '2018-04-16', 'mid': 3.3666, 'no': '074/A/NBP/2018'},
#   {'effectiveDate': '2018-04-17', 'mid': 3.3572, 'no': '075/A/NBP/2018'},
#   {'effectiveDate': '2018-04-18', 'mid': 3.3721, 'no': '076/A/NBP/2018'},
# ...

# %%
df2
# Out:
# {'code': 'EUR',
#  'currency': 'euro',
#  'rates': [{'effectiveDate': '2018-04-03',
#    'mid': 4.2094,
#    'no': '065/A/NBP/2018'},
#   {'effectiveDate': '2018-04-04', 'mid': 4.2065, 'no': '066/A/NBP/2018'},
#   {'effectiveDate': '2018-04-05', 'mid': 4.207, 'no': '067/A/NBP/2018'},
#   {'effectiveDate': '2018-04-06', 'mid': 4.1984, 'no': '068/A/NBP/2018'},
#   {'effectiveDate': '2018-04-09', 'mid': 4.1967, 'no': '069/A/NBP/2018'},
#   {'effectiveDate': '2018-04-10', 'mid': 4.199, 'no': '070/A/NBP/2018'},
#   {'effectiveDate': '2018-04-11', 'mid': 4.1911, 'no': '071/A/NBP/2018'},
#   {'effectiveDate': '2018-04-12', 'mid': 4.1882, 'no': '072/A/NBP/2018'},
#   {'effectiveDate': '2018-04-13', 'mid': 4.1769, 'no': '073/A/NBP/2018'},
#   {'effectiveDate': '2018-04-16', 'mid': 4.1628, 'no': '074/A/NBP/2018'},
#   {'effectiveDate': '2018-04-17', 'mid': 4.1582, 'no': '075/A/NBP/2018'},
#   {'effectiveDate': '2018-04-18', 'mid': 4.1677, 'no': '076/A/NBP/2018'},
# ...

# %%
df_new = pd.concat([df1, df2])
df_new
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-b50542574c6f> in <module>()
# ----> 1 df_new = pd.concat([df1, df2])
#       2 df_new
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/tools/merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#    1449                        keys=keys, levels=levels, names=names,
#    1450                        verify_integrity=verify_integrity,
# -> 1451                        copy=copy)
#    1452     return op.get_result()
#    1453
#
# /home/kodolamacz/anaconda3/lib/python3.6/site-packages/pandas/tools/merge.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#    1506         for obj in objs:
#    1507             if not isinstance(obj, NDFrame):
# ...
